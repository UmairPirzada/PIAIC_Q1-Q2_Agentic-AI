# %% [markdown]
# <a href="https://colab.research.google.com/github/UmairPirzada/PIAIC_Q1-Q2_Agentic-AI/blob/main/Crewai_Research_Agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install --upgrade crewai crewai-tools
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.0/235.0 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.9/542.9 kB 25.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.0/134.0 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.4/211.4 kB 14.1 MB/s eta 0:00:00
# ...

# %%
!  pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
! pip install --upgrade crewai

# %%
! conda create -n master-crewai-course python=3.12
# Out:
# /bin/bash: line 1: conda: command not found

# %%
! crewai create flow project1
# Out:
# Creating flow project1...
# Flow project1 created successfully!

# %%
! pip install uv

# %%
! pip install crewai  'crewai[tools]'

# %%
! pip install crewai  'crewai[tools]'

# %%
! crewai create crew ai-latest-development
# Out:
# Creating folder ai_latest_development...
# Cache expired or not found. Fetching provider data from the web...
# ...
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your GEMINI API key (press Enter to skip): AIzaSyBWHFFWFZxjgw454xDJ7Av_Af_7HVrFf4M
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-flash
#   - Created ai_latest_development/.gitignore
#   - Created ai_latest_development/pyproject.toml
#   - Created ai_latest_development/README.md
#   - Created ai_latest_development/knowledge/user_preference.txt
# ...

# %%
cd /content/ai_latest_development/src/ai_latest_development
# Out:
# /content/ai_latest_development/src/ai_latest_development

# %%
! uv run main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# langchain  ------------------------------ 445.86 KiB/986.36 KiB
# jedi       ------------------------------ 445.74 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# Building ai-latest-development @ file:///content/ai_latest_development
# ⠋ Preparing packages... (113/212)
# build      ------------------------------     0 B/22.41 KiB
# pyjwt      ------------------------------     0 B/22.46 KiB
# markupsafe ------------------------------ 14.88 KiB/22.58 KiB
# asgiref    ------------------------------ 14.88 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 14.88 KiB/23.95 KiB
# importlib-metadata ------------------------------ 14.87 KiB/25.89 KiB
# executing  ------------------------------ 14.88 KiB/26.08 KiB
# referencing ------------------------------ 14.88 KiB/26.15 KiB
# ...

# %%
! uv run ai_latest_development
# Out:
# Building ai-latest-development @ file:///content/ai_latest_development
# Building ai-latest-development @ file:///content/ai_latest_development
# Building ai-latest-development @ file:///content/ai_latest_development
#    Built ai-latest-development @ file:///content/ai_latest_development
# Uninstalled 1 package in 0.93ms
# Installed 1 package in 2ms
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2025.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# ...
